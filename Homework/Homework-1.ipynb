# %% [markdown]
# # MTH 4320 / 5320 - Homework 1
#
# ## Multivariate Linear Regression and Gradient Descent
#
# **Deadline**: announced in Canvas
#
# **Points**: 50
#
# ### Instructions
#
# - Submit **one** Jupyter notebook file and (optionally) **one** PDF with your handwritten work. Alternatively, type mathematical solutions in markdown cells in the notebook.
#
#     - Your notebook file must include text explanations of your work, well-commented code, and the outputs from your code.
#
#     - All mathematical work must be shown for written/typed problems.
#
#     - Your programming work should use NumPy and scikit-learn-style class structure. You may use scikit-learn utilities for data loading, preprocessing, splitting, and metrics, but the gradient descent model itself must be your own implementation.
#
# ## Problems
#
# ### Problem 1 - Multivariate Linear Regression Model and Loss (10 pts)
#
# A multivariate linear regression model has $d$ input features and $m$ output variables. For a dataset with $n$ examples, write the model using matrix notation. Incorporate the bias/intercept term into the weight matrix by adding a column of ones to the input matrix.
#
# Write the formula for the predicted outputs and the mean squared error (MSE) loss over the dataset. Then determine and state the dimensions of each matrix or vector in your formulas.
#
# **Hint:** Since the model has multiple outputs, the weights form a matrix, not just a vector.
#
# ### Problem 2 - Gradient of the MSE Loss (20 pts)
#
# Using the notation from Problem 1, derive the gradient of the multivariate MSE loss with respect to the weight matrix. Show all work that the matrix calculus is clear, and state the final gradient formula.
#
# Derive the gradient of the multivariate MSE loss with respect to the weight matrix. Show your work and clearly identify the final formula for \(\nabla_W L\)
#
# ### Problem 3 - Implement Multivariate Linear Regression with Gradient Descent (5 pts)
#
# Implement a multivariate linear regression class using a scikit-learn-style structure. Your class must learn the weights using gradient descent.
#
# **Starter Code:**
#
# ```python
# import numpy as np
#
# class MultivariateLinearRegressionGD:
#     def __init__(self, learning_rate=1e-2, max_iter=1000, tolerance=1e-8):
#         # store hyperparameters here
#         # randomly initialize weights
#         pass
#
#     def fit(self, X, Y):
#         # validate inputs
#         # add the bias column
#         # initialize weights
#         # run gradient descent
#         # store learned parameters as attributes
#         return self
#
#     def predict(self, X):
#         # add the bias column
#         # return model predictions
#         pass
# ```
#
# Implement `fit` and `predict`. Store the learned weight matrix as `self.coef_`, following common scikit-learn naming conventions. Store a loss history so you can plot the optimization curve.
#
# ### Problem 4 - Multiple Random Initializations (10 pts)
#
# Extend your class so it can start from multiple random initializations and select the weights that give the best validation performance.
#
# Modify `fit` so that it accepts training data and a separate validation set. After all initializations are complete, select and store the weight matrix with the lowest validation MSE. Add initializer arguments such as `n_initializations`, `random_state`, and any others.
#
# Add a function to report the validation MSE for every initialization and identify the selected initialization, using printouts and/or plots.
#
# ### Problem 5 - Apply Your Model to the Linnerud Dataset (5 pts)
#
# Apply your multivariate regression implementation to the Linnerud dataset from scikit-learn: `sklearn.datasets.load_linnerud()`. The Linnerud dataset is a small exercise physiology dataset with 20 observations. The input features are exercise measurements: chin-ups, sit-ups, and jumps. The output variables are physiological measurements: weight, waist, and pulse. This makes it a compact real multivariate regression problem: each person has one input vector and three target values.
#
# Split the data into training, validation, and test sets. Use the training and validation sets to select hyperparameters such as the learning rate, maximum number of iterations, convergence tolerance, and number of random initializations. Reserve the test set exclusively for the final evaluation.
#
# Fit your gradient descent model using the multiple-random-initialization procedure from Problem 4 with `n_initializations > 1`. Use validation MSE to select the best initialization and retain its learned weights. Report the MSE for each initialization, identify the selected initialization, and report the final training, validation, and test MSE. Briefly discuss model fit, optimization, the effect of multiple initializations, and the limitations of using such a small dataset, using idiagrams as appropriate.
